# %% [raw]
# .. _norhand_example:
#
# Worked example: Inspecting an HTR model
# =======================================

# %% [markdown]
# In this example, we will see how Stringalign can be used to inspect the performance of a handwritten text recognition (HTR) model ([Sprakbanken/TrOCR-norhand-v3](https://huggingface.co/Sprakbanken/TrOCR-norhand-v3)) on the test set of the [Teklia/NorHand-v3](https://huggingface.co/datasets/Teklia/NorHand-v3-line) dataset.
#
# This analysis will focus on word accuracies, as that's were we've found the most interesting results for this model, but you can use the exact same strategy to investigate character errors as well.

# %% [markdown]
# ## Imports and loading the data

# %%
from collections import Counter

import pandas as pd
import stringalign
from IPython.display import HTML, display
from ipywidgets import interact
from stringalign.evaluate import MultiAlignmentAnalyzer

# %%
dataset = pd.read_json("data/transcription.json")

# %% [markdown]
# ## Create the multi-alignment analyzer
#
# First, we create the multi-alignment analyzer. Notice that we also include metadata this time. This makes it easy to cross reference between the alignment analyzer instances and the rows in the dataset.

# %%
multi_analyzer = MultiAlignmentAnalyzer.from_strings(
    references=dataset["reference"],
    predictions=dataset["predicted"],
    metadata=[{"img_path": row.img, "index": row.Index} for row in dataset.itertuples()],
    tokenizer=stringalign.tokenize.UnicodeWordTokenizer(),
)

# %% [markdown]
# ## Compute WER
# The first thing we do is compute the token error rate, which in this case equates to the WER

# %%
print(f"The WER is: {multi_analyzer.compute_ter():.2%}")
# Out:
# The WER is: 15.05%

# %% [markdown]
# ## Find most common edits
#
# After computing the WER, it can be useful to see the most common edits made by the algorithm.

# %%
for edit, count in multi_analyzer.edit_counts["raw"].most_common(5):
    print(f"Edit {edit} occured {count} times.")
# Out:
# Edit REPLACED 'jej' -> 'jeg' occured 7 times.
# Edit REPLACED 'Ivar' -> 'Svar' occured 7 times.
# Edit REPLACED 'eg' -> 'og' occured 7 times.
# Edit REPLACED 'De' -> 'de' occured 4 times.
# Edit DELETED  '1' occured 3 times.

# %% [markdown]
# ### Accounting for multiple possible optimal alignments
#
# As discussed in [Sequence alignment](concepts/sequence_alignment.rst), the optimal alignment is not unique, so we compute can double check the stability by randomising the selected optimal alignments and computing average counts.
#
# In reality, it would be nice to compute the standard deviation of the counts as well, but we'll skip that here. See e.g. *[Uncertainty metrics for token-specific statistics
# ](auto_examples/plot_sampling_alignments.rst)* for an example where we compute the standard deviation for edit operation counts.

# %%
num_random_samples = 10
multi_analyzers = [
    MultiAlignmentAnalyzer.from_strings(
        references=dataset["reference"],
        predictions=dataset["predicted"],
        metadata=[{"img_path": row.img, "index": row.Index} for row in dataset.itertuples()],
        tokenizer=stringalign.tokenize.UnicodeWordTokenizer(),
        randomize_alignment=True,
        random_state=i,
    )
    for i in range(num_random_samples)
]
edit_counts = sum((ma.edit_counts["raw"] for ma in multi_analyzers), start=Counter())

for edit, count in edit_counts.most_common(5):
    print(f"Edit {edit} occured in average {count / num_random_samples} times.")
# Out:
# Edit REPLACED 'Ivar' -> 'Svar' occured in average 7.0 times.
# Edit REPLACED 'eg' -> 'og' occured in average 7.0 times.
# Edit REPLACED 'jej' -> 'jeg' occured in average 6.3 times.
# Edit REPLACED 'De' -> 'de' occured in average 4.0 times.
# Edit DELETED  'er' occured in average 3.1 times.

# %% [markdown]
# We see that `'Ivar' -> 'Svar'` and `'eg' -> 'og'` are still the most common replacements, while `'jej' -> 'jeg'` has slightly fewer occurences.

# %% [markdown]
# ## Visualising the most common edits
#
# Let's now use Stringalign's visualisation tools to look at the three most common edits. We'll do that with an interactive plot with the edit operations in sorted order.

# %%
for edit, _count in edit_counts.most_common(3):
    display(HTML(f"<h3>{edit}</h3>"))
    for aa in multi_analyzer.alignment_operator_index["raw"][edit]:
        image = stringalign.visualize.create_html_image(f"data/images/{aa.metadata['img_path']}")

        # Each token is a word without spaces, so we add a space between each alignment operator
        alignment_html = aa.visualize(space_alignment_ops=True)
        display(HTML(image + alignment_html))
# Out:
# <h3>REPLACED 'Ivar' -> 'Svar'</h3>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Herr</span> <span class="kept predicted">Herr</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Hr</span> <span class="kept predicted">Hr</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Herr</span> <span class="kept predicted">Herr</span></div><div class='alignment-chunk spaced'><span class="replaced reference">filol</span> <span class="replaced predicted">fuld</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Hr</span> <span class="kept predicted">Hr</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Aasen</span> <span class="replaced predicted">stasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Hr</span> <span class="kept predicted">Hr</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Ivar</span> <span class="replaced predicted">Svar</span></div><div class='alignment-chunk spaced'><span class="kept reference">Aasen</span> <span class="kept predicted">Aasen</span></div></div>
# <h3>REPLACED 'eg' -> 'og'</h3>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">og</span> <span class="kept predicted">og</span></div><div class='alignment-chunk spaced'><span class="kept reference">som</span> <span class="kept predicted">som</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="kept reference">gjerne</span> <span class="kept predicted">gjerne</span></div><div class='alignment-chunk spaced'><span class="kept reference">vilde</span> <span class="kept predicted">vilde</span></div><div class='alignment-chunk spaced'><span class="replaced reference">nemne</span> <span class="replaced predicted">henvæ</span></div><div class='alignment-chunk spaced'><span class="kept reference">for</span> <span class="kept predicted">for</span></div><div class='alignment-chunk spaced'><span class="kept reference">for</span> <span class="kept predicted">for</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="replaced reference">De</span> <span class="replaced predicted">Da</span></div><div class='alignment-chunk spaced'><span class="kept reference">har</span> <span class="kept predicted">har</span></div><div class='alignment-chunk spaced'><span class="replaced reference">fått</span> <span class="replaced predicted">fitt</span></div><div class='alignment-chunk spaced'><span class="replaced reference">ein</span> <span class="replaced predicted">in</span></div><div class='alignment-chunk spaced'><span class="replaced reference">ansvarsfull</span> <span class="replaced predicted">ansvarsfall</span></div><div class='alignment-chunk spaced'><span class="replaced reference">post</span> <span class="replaced predicted">part</span></div><div class='alignment-chunk spaced'><span class="replaced reference">på</span> <span class="replaced predicted">paa</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Noregs</span> <span class="replaced predicted">Norge</span></div><div class='alignment-chunk spaced'><span class="replaced reference">største</span> <span class="replaced predicted">støgete</span></div><div class='alignment-chunk spaced'><span class="replaced reference">talarstol</span> <span class="replaced predicted">tilestol</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="kept reference">vil</span> <span class="kept predicted">vil</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Det</span> <span class="kept predicted">Det</span></div><div class='alignment-chunk spaced'><span class="kept reference">var</span> <span class="kept predicted">var</span></div><div class='alignment-chunk spaced'><span class="replaced reference">ein</span> <span class="replaced predicted">sin</span></div><div class='alignment-chunk spaced'><span class="kept reference">liten</span> <span class="kept predicted">liten</span></div><div class='alignment-chunk spaced'><span class="kept reference">ting</span> <span class="kept predicted">ting</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="kept reference">kom</span> <span class="kept predicted">kom</span></div><div class='alignment-chunk spaced'><span class="kept reference">til</span> <span class="kept predicted">til</span></div><div class='alignment-chunk spaced'><span class="kept reference">aa</span> <span class="kept predicted">aa</span></div><div class='alignment-chunk spaced'><span class="replaced reference">tenkje</span> <span class="replaced predicted">hurtige</span></div><div class='alignment-chunk spaced'><span class="kept reference">paa</span> <span class="kept predicted">paa</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="replaced reference">sård</span> <span class="replaced predicted">sért</span></div><div class='alignment-chunk spaced'><span class="replaced reference">så</span> <span class="replaced predicted">nu</span></div><div class='alignment-chunk spaced'><span class="replaced reference">ber</span> <span class="replaced predicted">led</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="replaced reference">um</span> <span class="replaced predicted">min</span></div><div class='alignment-chunk spaced'><span class="replaced reference">tilgjeving</span> <span class="replaced predicted">tilgjæring</span></div><div class='alignment-chunk spaced'><span class="kept reference">Og</span> <span class="kept predicted">Og</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">vilde</span> <span class="kept predicted">vilde</span></div><div class='alignment-chunk spaced'><span class="replaced reference">vere</span> <span class="replaced predicted">verre</span></div><div class='alignment-chunk spaced'><span class="replaced reference">takksam</span> <span class="replaced predicted">takksom</span></div><div class='alignment-chunk spaced'><span class="replaced reference">um</span> <span class="replaced predicted">nu</span></div><div class='alignment-chunk spaced'><span class="replaced reference">De</span> <span class="replaced predicted">de</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">heil</span> <span class="kept predicted">heil</span></div><div class='alignment-chunk spaced'><span class="replaced reference">brote</span> <span class="replaced predicted">brate</span></div><div class='alignment-chunk spaced'><span class="replaced reference">bøker</span> <span class="replaced predicted">bake</span></div><div class='alignment-chunk spaced'><span class="replaced reference">kvart</span> <span class="replaced predicted">kraft</span></div><div class='alignment-chunk spaced'><span class="replaced reference">aar</span> <span class="replaced predicted">over</span></div><div class='alignment-chunk spaced'><span class="replaced reference">som</span> <span class="replaced predicted">dem</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="replaced reference">bryr</span> <span class="replaced predicted">bryt</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">vilde</span> <span class="kept predicted">vilde</span></div><div class='alignment-chunk spaced'><span class="replaced reference">take</span> <span class="replaced predicted">tale</span></div><div class='alignment-chunk spaced'><span class="kept reference">meg</span> <span class="kept predicted">meg</span></div><div class='alignment-chunk spaced'><span class="replaced reference">på</span> <span class="replaced predicted">få</span></div><div class='alignment-chunk spaced'><span class="replaced reference">ordlyda</span> <span class="replaced predicted">ordbyd</span></div><div class='alignment-chunk spaced'><span class="kept reference">av</span> <span class="kept predicted">av</span></div><div class='alignment-chunk spaced'><span class="kept reference">det</span> <span class="kept predicted">det</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div><div class='alignment-chunk spaced'><span class="kept reference">skreiv</span> <span class="kept predicted">skreiv</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="replaced reference">mi</span> <span class="replaced predicted">nu</span></div><div class='alignment-chunk spaced'><span class="replaced reference">nokra</span> <span class="replaced predicted">noksa</span></div><div class='alignment-chunk spaced'><span class="kept reference">Kronur</span> <span class="kept predicted">Kronur</span></div><div class='alignment-chunk spaced'><span class="kept reference">so</span> <span class="kept predicted">so</span></div><div class='alignment-chunk spaced'><span class="kept reference">vart</span> <span class="kept predicted">vart</span></div><div class='alignment-chunk spaced'><span class="replaced reference">eg</span> <span class="replaced predicted">og</span></div></div>
# <h3>REPLACED 'jej' -> 'jeg'</h3>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">hvorpå</span> <span class="kept predicted">hvorpå</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">erklærede</span> <span class="kept predicted">erklærede</span></div><div class='alignment-chunk spaced'><span class="kept reference">ham</span> <span class="kept predicted">ham</span></div><div class='alignment-chunk spaced'><span class="kept reference">at</span> <span class="kept predicted">at</span></div><div class='alignment-chunk spaced'><span class="kept reference">isåfald</span> <span class="kept predicted">isåfald</span></div><div class='alignment-chunk spaced'><span class="kept reference">måtte</span> <span class="kept predicted">måtte</span></div><div class='alignment-chunk spaced'><span class="kept reference">sagen</span> <span class="kept predicted">sagen</span></div><div class='alignment-chunk spaced'><span class="kept reference">betrag</span> <span class="kept predicted">betrag</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">ste</span> <span class="kept predicted">ste</span></div><div class='alignment-chunk spaced'><span class="kept reference">vilkår</span> <span class="kept predicted">vilkår</span></div><div class='alignment-chunk spaced'><span class="kept reference">angår</span> <span class="kept predicted">angår</span></div><div class='alignment-chunk spaced'><span class="kept reference">da</span> <span class="kept predicted">da</span></div><div class='alignment-chunk spaced'><span class="kept reference">går</span> <span class="kept predicted">går</span></div><div class='alignment-chunk spaced'><span class="kept reference">Finnes</span> <span class="kept predicted">Finnes</span></div><div class='alignment-chunk spaced'><span class="kept reference">forlangende</span> <span class="kept predicted">forlangende</span></div><div class='alignment-chunk spaced'><span class="kept reference">såvidt</span> <span class="kept predicted">såvidt</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">rer</span> <span class="kept predicted">rer</span></div><div class='alignment-chunk spaced'><span class="kept reference">O</span> <span class="kept predicted">O</span></div><div class='alignment-chunk spaced'><span class="kept reference">Bakke</span> <span class="kept predicted">Bakke</span></div><div class='alignment-chunk spaced'><span class="kept reference">der</span> <span class="kept predicted">der</span></div><div class='alignment-chunk spaced'><span class="kept reference">også</span> <span class="kept predicted">også</span></div><div class='alignment-chunk spaced'><span class="kept reference">efter</span> <span class="kept predicted">efter</span></div><div class='alignment-chunk spaced'><span class="kept reference">hvad</span> <span class="kept predicted">hvad</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">har</span> <span class="kept predicted">har</span></div><div class='alignment-chunk spaced'><span class="kept reference">hørt</span> <span class="kept predicted">hørt</span></div><div class='alignment-chunk spaced'><span class="kept reference">dertil</span> <span class="kept predicted">dertil</span></div><div class='alignment-chunk spaced'><span class="kept reference">skal</span> <span class="kept predicted">skal</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Hvad</span> <span class="kept predicted">Hvad</span></div><div class='alignment-chunk spaced'><span class="kept reference">derimod</span> <span class="kept predicted">derimod</span></div><div class='alignment-chunk spaced'><span class="kept reference">angår</span> <span class="kept predicted">angår</span></div><div class='alignment-chunk spaced'><span class="kept reference">det</span> <span class="kept predicted">det</span></div><div class='alignment-chunk spaced'><span class="kept reference">andet</span> <span class="kept predicted">andet</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">vil</span></div><div class='alignment-chunk spaced'><span class="replaced reference">vilkår</span> <span class="replaced predicted">kår</span></div><div class='alignment-chunk spaced'><span class="kept reference">da</span> <span class="kept predicted">da</span></div><div class='alignment-chunk spaced'><span class="kept reference">har</span> <span class="kept predicted">har</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">alle</span> <span class="kept predicted">alle</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">gjøre</span> <span class="kept predicted">gjøre</span></div><div class='alignment-chunk spaced'><span class="kept reference">det</span> <span class="kept predicted">det</span></div><div class='alignment-chunk spaced'><span class="kept reference">fornødne</span> <span class="kept predicted">fornødne</span></div><div class='alignment-chunk spaced'><span class="kept reference">med</span> <span class="kept predicted">med</span></div><div class='alignment-chunk spaced'><span class="replaced reference">Finne</span> <span class="replaced predicted">Tinne</span></div><div class='alignment-chunk spaced'><span class="kept reference">og</span> <span class="kept predicted">og</span></div><div class='alignment-chunk spaced'><span class="deleted reference">2</span> <span class="deleted predicted"></span></div><div class='alignment-chunk spaced'><span class="replaced reference">at</span> <span class="replaced predicted">sat</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">skulde</span> <span class="kept predicted">skulde</span></div><div class='alignment-chunk spaced'><span class="kept reference">overta</span> <span class="kept predicted">overta</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">rede</span> <span class="kept predicted">rede</span></div><div class='alignment-chunk spaced'><span class="kept reference">tidligere</span> <span class="kept predicted">tidligere</span></div><div class='alignment-chunk spaced'><span class="kept reference">erklæret</span> <span class="kept predicted">erklæret</span></div><div class='alignment-chunk spaced'><span class="kept reference">Tønsberg</span> <span class="kept predicted">Tønsberg</span></div><div class='alignment-chunk spaced'><span class="kept reference">at</span> <span class="kept predicted">at</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">under</span> <span class="kept predicted">under</span></div><div class='alignment-chunk spaced'><span class="kept reference">ingen</span> <span class="kept predicted">ingen</span></div><div class='alignment-chunk spaced'><span class="kept reference">om</span> <span class="kept predicted">om</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="kept reference">Efter</span> <span class="kept predicted">Efter</span></div><div class='alignment-chunk spaced'><span class="kept reference">aftale</span> <span class="kept predicted">aftale</span></div><div class='alignment-chunk spaced'><span class="kept reference">har</span> <span class="kept predicted">har</span></div><div class='alignment-chunk spaced'><span class="replaced reference">jej</span> <span class="replaced predicted">jeg</span></div><div class='alignment-chunk spaced'><span class="kept reference">været</span> <span class="kept predicted">været</span></div><div class='alignment-chunk spaced'><span class="kept reference">hos</span> <span class="kept predicted">hos</span></div><div class='alignment-chunk spaced'><span class="kept reference">konsul</span> <span class="kept predicted">konsul</span></div><div class='alignment-chunk spaced'><span class="kept reference">Tønsberg</span> <span class="kept predicted">Tønsberg</span></div><div class='alignment-chunk spaced'><span class="kept reference">for</span> <span class="kept predicted">for</span></div><div class='alignment-chunk spaced'><span class="kept reference">at</span> <span class="kept predicted">at</span></div></div>

# %% [markdown]
# When we e.g. inspect the errors where `'Ivar'` is transcribed as `'Svar'`, we see that the `'I'` very often looks like an `'S'`. Moreover, "Ivar" is a name, while "Svar" is the Norwegian word for "Reply", which could indicate that the model struggles with names.
#
# We also see that while the `'eg' -> 'og'` replacement can make visual in most cases, it does often resemble `'eg'` more than `'og'`. Furthermore, both `'eg'` and `'jej'` are synonyms with `'jeg'`, but `'eg'` is Nynorsk and "jej" is a non-standard spelling. Thus, the model may struggle with other Norwegian written dialects than Bokmål.

# %% [markdown]
# ## Inspecting the lines with the lowest WER
#
# Another thing that can be very useful is inspecting the lines with the highest error rate to see if there is any pattern.

# %%
# Look at the three lines with the lowest WER
alignment_analyzers = sorted(multi_analyzer.alignment_analyzers, key=lambda aa: aa.compute_ter(), reverse=True)

for aa in alignment_analyzers[:5]:
    image = stringalign.visualize.create_html_image(f"data/images/{aa.metadata['img_path']}")
    alignment_html = aa.visualize(space_alignment_ops=True)
    display(HTML(image + alignment_html))
# Out:
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">TEATAere</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">R</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">b</span></div><div class='alignment-chunk spaced'><span class="replaced reference">THEATERCHEFEN</span> <span class="replaced predicted">EN</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">K</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">TJESeJSK</span></div><div class='alignment-chunk spaced'><span class="replaced reference">AKTIESELSKABET</span> <span class="replaced predicted">sRET</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">NORSES</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">FJSKERe</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">BJØR</span></div><div class='alignment-chunk spaced'><span class="replaced reference">NORGES</span> <span class="replaced predicted">Ke</span></div><div class='alignment-chunk spaced'><span class="replaced reference">FISKERISTYRELSE</span> <span class="replaced predicted">BLE</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">FORSø</span></div><div class='alignment-chunk spaced'><span class="replaced reference">FORSØGSSTATIONEN</span> <span class="replaced predicted">GSTATIONALONEN</span></div></div>
# <img src="......" width="500px" /><style>.alignment { font-family: monospace; text-align: left; --kept: hsl(198, 71%, 68%); --replaced: hsl(41, 100%, 75%); --inserted: hsl(0, 71%, 84%); --neutral: #fff; font-size: 1rem; } .alignment-chunk, .alignment-labels { display: inline-block; min-width: 1ex; } .alignment-chunk.spaced { margin-left: 0.5em; } span.reference, span.predicted { white-space: pre; display: block; text-align: center; } .kept.reference, .kept.predicted { background-color: var(--kept); } .deleted.reference { background-color: var(--inserted); } .deleted.predicted::after, .inserted.reference::after { content: "-"; } .inserted.predicted { background-color: var(--inserted); } .replaced.reference, .replaced.predicted{ background-color: var(--replaced); }</style><div class="alignment"><div class="alignment-labels"><span class="reference label">Reference:</span><span class="predicted label">Predicted:</span></div><div class='alignment-chunk spaced'><span class="inserted reference"></span> <span class="inserted predicted">21.7</span></div><div class='alignment-chunk spaced'><span class="replaced reference">21.7.1882</span> <span class="replaced predicted">1882</span></div></div>

# %% [markdown]
# In this case, we see that most of the lines with the highest error rate consists of printed text, so if we want to improve the model, including printed text could be a useful path to consider.

# %% [markdown]
# ## Conclusion
#
# We see that Stringalign can be useful in finding what errors an automatic transcription model makes, which can help inform us if a given model is suited for a task, and how we could improve a given model's performance.
